# %% [markdown]
# # Left Knee

# %%
import cv2
import numpy as np
import mediapipe as mp

mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

def calculate_angle(a, b, c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)

    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - \
              np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)

    if angle > 180.0:
        angle = 360 - angle
    return angle

cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

counter = 0
stage = None
rep_completed = False
started = False

target_reps = int(input("Enter number of reps: "))

with mp_pose.Pose(min_detection_confidence=0.5,
                  min_tracking_confidence=0.5) as pose:
    
    first_rep_skipped = False
    
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame, 1)

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = pose.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            landmarks = results.pose_landmarks.landmark

            hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,
                   landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,
                    landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,
                     landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]

            angle = calculate_angle(hip, knee, ankle)

            cv2.putText(image, str(int(angle)),
                        tuple(np.multiply(knee, [640, 480]).astype(int)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2, cv2.LINE_AA)

            if angle > 150:
                if not started:
                    started = True
                else:
                    stage = "up"
                    rep_completed = True

            if angle < 120 and stage == "up":
                if rep_completed:
                    if not first_rep_skipped:
                        first_rep_skipped = True
                        rep_completed = False
                    else:
                        counter += 1
                        rep_completed = False
                        print(f"Rep: {counter}")

                        if counter >= target_reps:
                            message = "Excellent! Knee extension complete"
                            cv2.putText(image, message, (30, 200),
                                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3, cv2.LINE_AA)
                            cv2.imshow('Mediapipe Feed', image)
                            cv2.waitKey(1500)
                            break

        except:
            pass

        cv2.rectangle(image, (0, 0), (225, 73), (245, 117, 16), -1)
        cv2.putText(image, 'REPS', (15, 12),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
        cv2.putText(image, str(counter), (10, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 255), 2, cv2.LINE_AA)

        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks,
                                      mp_pose.POSE_CONNECTIONS,
                                      mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                                      mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1747062396.523993   23922 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 83), renderer: Apple M1
# W0000 00:00:1747062396.656922   27684 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1747062396.677774   27684 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 1   HIToolbox                           0x00000001b23bc5c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001b23bc188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x00000001b23298bc _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1184
# 4   HIToolbox                           0x00000001b23bc004 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 180
# 5   AppKit                              0x00000001ac1abd30 -[NSApplication _setPresentationOptions:instance:flags:] + 956
# 6   AppKit                              0x00000001ac04193c -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 404
# 7   CoreFoundation                      0x00000001a8c5e560 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 8   CoreFoundation                      0x00000001a8cfc044 ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00000001a8cfbf8c _CFXRegistrationPost + 440
# 10  CoreFoundation                      0x00000001a8c2fb64 _CFXNotificationPost + 708
# 11  Foundation                          0x00000001a9b1f38c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 12  AppKit                              0x00000001ac1ac2b4 spacesNotificationHandler + 96
# 13  SkyLight                            0x00000001ad899214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 14  SkyLight                            0x00000001ad897e10 CGSSnarfAndDispatchDatagrams + 808
# 15  SkyLight                            0x00000001adbbfa9c SLSGetNextEventRecordInternal + 344
# 16  SkyLight                            0x00000001ad9c0fb0 SLEventCreateNextEvent + 16
# 17  HIToolbox                           0x00000001b2354b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 18  HIToolbox                           0x00000001b2354ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 19  CoreFoundation                      0x00000001a8c99410 __CFMachPortPerform + 260
# 20  CoreFoundation                      0x00000001a8c69f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 21  CoreFoundation                      0x00000001a8c69eb8 __CFRunLoopDoSource1 + 520
# 22  CoreFoundation                      0x00000001a8c688a4 __CFRunLoopRun + 2264
# 23  CoreFoundation                      0x00000001a8c67878 CFRunLoopRunSpecific + 612
# 24  HIToolbox                           0x00000001b2347fa0 RunCurrentEventLoopInMode + 292
# 25  HIToolbox                           0x00000001b2347de4 ReceiveNextEventCommon + 672
# 26  HIToolbox                           0x00000001b2347b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 27  AppKit                              0x00000001abeed84c _DPSNextEvent + 632
# 28  AppKit                              0x00000001abeec9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 29  cv2.abi3.so                         0x000000015bbe4768 cvWaitKey + 224
# 30  cv2.abi3.so                         0x000000015bbdf388 _ZN2cv9waitKeyExEi + 236
# 31  cv2.abi3.so                         0x000000015bbdf47c _ZN2cv7waitKeyEi + 48
# 32  cv2.abi3.so                         0x000000015ad920bc _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 33  python3.11                          0x0000000104ea847c cfunction_call + 60
# 34  python3.11                          0x0000000104f8a7b4 _PyEval_EvalFrameDefault + 194180
# 35  python3.11                          0x0000000104f586ac _PyEval_Vector + 464
# 36  python3.11                          0x0000000104f5844c PyEval_EvalCode + 248
# 37  python3.11                          0x0000000104f53698 builtin_exec + 332
# 38  python3.11                          0x0000000104f8e1d4 _PyEval_EvalFrameDefault + 209060
# 39  python3.11                          0x0000000104e62c28 gen_send_ex2 + 204
# 40  python3.11                          0x0000000104f65ae8 _PyEval_EvalFrameDefault + 43448
# 41  python3.11                          0x0000000104e62c28 gen_send_ex2 + 204
# 42  python3.11                          0x0000000104f65ae8 _PyEval_EvalFrameDefault + 43448
# 43  python3.11                          0x0000000104e62c28 gen_send_ex2 + 204
# 44  python3.11                          0x0000000104e63380 gen_send + 52
# 45  python3.11                          0x0000000104e578e8 method_vectorcall_O + 104
# 46  python3.11                          0x0000000104f8a5c0 _PyEval_EvalFrameDefault + 193680
# 47  python3.11                          0x0000000104e46174 _PyFunction_Vectorcall + 476
# 48  python3.11                          0x0000000104e4be64 method_vectorcall + 272
# 49  python3.11                          0x0000000104f8f48c _PyEval_EvalFrameDefault + 213852
# 50  python3.11                          0x0000000104e62c28 gen_send_ex2 + 204
# 51  python3.11                          0x0000000104f65ae8 _PyEval_EvalFrameDefault + 43448
# 52  python3.11                          0x0000000104e62c28 gen_send_ex2 + 204
# 53  python3.11                          0x0000000104f65ae8 _PyEval_EvalFrameDefault + 43448
# 54  python3.11                          0x0000000104e62c28 gen_send_ex2 + 204
# 55  python3.11                          0x0000000104f65ae8 _PyEval_EvalFrameDefault + 43448
# 56  python3.11                          0x0000000104e62c28 gen_send_ex2 + 204
# 57  python3.11                          0x0000000104f65ae8 _PyEval_EvalFrameDefault + 43448
# 58  python3.11                          0x0000000104e62c28 gen_send_ex2 + 204
# 59  python3.11                          0x0000000104f65ae8 _PyEval_EvalFrameDefault + 43448
# 60  python3.11                          0x0000000104e62c28 gen_send_ex2 + 204
# 61  _asyncio.cpython-311-darwin.so      0x0000000106824370 task_step_impl + 440
# 62  _asyncio.cpython-311-darwin.so      0x0000000106824128 task_step + 68
# 63  _asyncio.cpython-311-darwin.so      0x0000000106824c30 task_wakeup + 136
# 64  python3.11                          0x0000000104ea8e4c cfunction_vectorcall_O + 92
# 65  python3.11                          0x0000000104fb2b54 _PyObject_VectorcallTstate.4602 + 88
# 66  python3.11                          0x0000000104fb2a18 context_run + 92
# 67  python3.11                          0x0000000104ea912c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 68  python3.11                          0x0000000104f8f538 _PyEval_EvalFrameDefault + 214024
# 69  python3.11                          0x0000000104f586ac _PyEval_Vector + 464
# 70  python3.11                          0x0000000104f5844c PyEval_EvalCode + 248
# 71  python3.11                          0x0000000104f53698 builtin_exec + 332
# 72  python3.11                          0x0000000104ea912c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 73  python3.11                          0x0000000104f8a5c0 _PyEval_EvalFrameDefault + 193680
# 74  python3.11                          0x0000000104e46174 _PyFunction_Vectorcall + 476
# 75  python3.11                          0x0000000105012da8 pymain_run_module + 212
# 76  python3.11                          0x0000000105012840 Py_RunMain + 1292
# 77  python3.11                          0x0000000104ddece0 main + 56
# 78  dyld                                0x00000001a885fe50 start + 2544
# Rep: 1
# Rep: 2
# Rep: 3
# Rep: 4
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
